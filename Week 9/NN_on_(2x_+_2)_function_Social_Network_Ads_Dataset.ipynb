# %% [markdown]
# <a href="https://colab.research.google.com/github/yuzzaf/Course-Machine-Learning/blob/main/Week%209/NN_on_(2x_%2B_2)_function_Social_Network_Ads_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Nama: Muhammad Yuzzaf Ibrahim Azzumarafi
# ##NIM: 1103200082
# ##**NN on (2x + 2) Function**

# %%
import numpy as np
import tensorflow as tf

# %%
# Generate some random data for training
np.random.seed(0)
X_train = np.random.rand(100, 1) * 10  # Random values for x between 0 and 10
y_train = 2 * X_train + 2 + np.random.randn(100, 1)  # Adding some noise

# Define the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)  # Output layer with one neuron
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, verbose=2)

# Generate some test data
X_test = np.array([[1.0], [2.0], [3.0]])

# Make predictions using the trained model
y_pred = model.predict(X_test)

# Display the predictions
for i in range(len(X_test)):
    print(f'Input: {X_test[i][0]}, Predicted Output: {y_pred[i][0]}')
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 470.8580 - 512ms/epoch - 128ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 469.7638 - 13ms/epoch - 3ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 468.7124 - 12ms/epoch - 3ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 467.5952 - 12ms/epoch - 3ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 466.5258 - 11ms/epoch - 3ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 465.4124 - 14ms/epoch - 4ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 464.3368 - 16ms/epoch - 4ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 463.2646 - 17ms/epoch - 4ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 462.1642 - 13ms/epoch - 3ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 461.0515 - 12ms/epoch - 3ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 459.9607 - 12ms/epoch - 3ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 458.8676 - 13ms/epoch - 3ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 457.8430 - 12ms/epoch - 3ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 456.7335 - 13ms/epoch - 3ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 455.7189 - 17ms/epoch - 4ms/step
# ...

# %% [markdown]
# ## neural network yang dilatih tampaknya kesulitan untuk mempelajari hubungan linier dari fungsi (2x + 2). Nilai loss cukup tinggi, mengindikasikan bahwa ada perbedaan yang signifikan antara nilai prediksi dan nilai aktual.
